# %% [markdown]
# ## Working with fundamental data
#
#
# #### Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### Reading income statements

# %%
files = os.listdir('data/IncomeStatement/')
period = 'annual' # 'quarterly' # 'annual'

tickers = ['AAPL']

for t in tickers: 
    for f in files:   # Oops...
        if t in f and period in f:  
            filename = f
            print(f)
# Out:
# AAPL-Income-Statement-annual-24-02-2021-17-23.csv

# %% [markdown]
# #### Auxiliar function
#
# This function creates a DF from the IncomeStatement, then it uses it to create a table with all the tickers and its income data.

# %%
def create_df_ticker(ticker_name, Statement_type, filename):
    """Given the name of the .csv file it returns a dataframe for a single ticker."""    
    # Read file
    income_ticker = pd.read_csv('data/' + Statement_type + '/' + filename, skiprows = 1)
    
    # Rename column
    income_ticker.columns = ['Data'] + list(income_ticker.columns[1:])
    # income_ticker.rename(columns = {'Fiscal year ends in September. USD in millions except per share data.': 'Data'}, inplace = True)
    
    # Fixing duplicated data names
    eps_index = income_ticker[income_ticker.iloc[:,0] == 'Earnings per share'].index[0]
    income_ticker.iloc[eps_index + 1, 0] += ' ' + income_ticker.iloc[eps_index, 0]
    income_ticker.iloc[eps_index + 2, 0] += ' ' + income_ticker.iloc[eps_index, 0]
    #income_ticker = pd.concat([income_ticker.iloc[:eps_index], income_ticker.iloc[eps_index+1:]])

    waso_index = income_ticker[income_ticker.iloc[:,0] == 'Weighted average shares outstanding'].index[0]
    income_ticker.iloc[waso_index + 1, 0] += ' ' + income_ticker.iloc[waso_index, 0]
    income_ticker.iloc[waso_index + 2, 0] += ' ' + income_ticker.iloc[waso_index, 0]
    #income_ticker = pd.concat([income_ticker.iloc[:waso_index], income_ticker.iloc[waso_index+1:]])
    income_ticker = income_ticker.set_index('Data').drop(['Operating expenses', 'Earnings per share', 'Weighted average shares outstanding'])

     # Change column names to eliminate month (we only care about years)
    income_ticker.columns = [x[:4] for x in income_ticker.columns]

    initial_year = int(income_ticker.columns[0])
    years_to_process = [str(initial_year + x) for x in range(1, 5)]  #skip first one...
    
    for x in ['Revenue', 'Cost of revenue', 'Gross profit', 'Income before taxes', 'Diluted Earnings per share',
              'Net income available to common shareholders']:
        
        if x not in income_ticker.index:
            income_ticker.loc[x] = np.nan  # Add full of NaN
        
        income_ticker.loc['Change % YoY {}'.format(x)] = np.nan
        for y in years_to_process:
            income_ticker.loc['Change % YoY' + x, y] = (income_ticker.loc[x, y] / income_ticker.loc[x, str(int(y)-1)] - 1) * 100
    
        
    income_ticker.reset_index(inplace = True)
    
    # Transposing
    income_ticker = income_ticker.transpose()
    income_ticker.reset_index(inplace = True)

    # Renaming columns as the first row
    income_ticker.columns = income_ticker.iloc[0].values

    # Dropping first row
    income_ticker = income_ticker.iloc[1:]
    
    # Creating 'Year' and 'Ticker' columns
    income_ticker['Year'] = income_ticker['Data'].str[:4]
    income_ticker['Ticker'] = ticker_name
    
    # Setting 'Ticker' as index, dropping and sorting columns
    #income_ticker.set_index('Ticker', inplace = True)
    income_ticker.drop(['Data'], axis = 1, inplace = True)
    income_ticker = income_ticker.iloc[:, [income_ticker.shape[1] - 1, income_ticker.shape[1] - 2] + list(range(income_ticker.shape[1] - 2))  ]
    
    return income_ticker

# %%
create_df_ticker('DE', 'IncomeStatement', 'DE-Income-Statement-annual-24-02-2021-18-10.csv')
# Out:
#   Ticker  Year  Revenue Cost of revenue Gross profit Research and development  \
# 1     DE  2016  26364.0         19175.0       7189.0                   1389.0
# 2     DE  2017  29116.0         21001.0       8115.0                   1368.0
# 3     DE  2018  37021.0         26986.0      10036.0                   1658.0
# 4     DE  2019  38941.0         28486.0      10455.0                   1783.0
# 5     DE  2020  35259.0         25112.0      10147.0                   1644.0
# 6     DE   TTM  35259.0         25112.0      10147.0                   1644.0
#
#   Sales, General and administrative Other operating expenses  \
# 1                            2952.0                    640.0
# 2                            3254.0                    732.0
# 3                            3630.0                    691.0
# 4                            3694.0                    915.0
# 5                            3677.0                    969.0
# 6                            3677.0                    969.0
#
#   Total operating expenses Operating income  ... Change % YoY Cost of revenue  \
# 1                   4981.0           2208.0  ...                          NaN
# 2                   5353.0           2761.0  ...                          NaN
# 3                   5979.0           4056.0  ...                          NaN
# 4                   6392.0           4063.0  ...                          NaN
# 5                   6290.0           3857.0  ...                          NaN
# 6                   6290.0           3857.0  ...                          NaN
#
#   Change % YoYCost of revenue Change % YoY Gross profit  \
# 1                         NaN                       NaN
# 2                    9.522816                       NaN
# 3                   28.498643                       NaN
# 4                    5.558438                       NaN
# 5                  -11.844415                       NaN
# 6                         NaN                       NaN
#
#   Change % YoYGross profit Change % YoY Income before taxes  \
# 1                      NaN                              NaN
# 2                 12.88079                              NaN
# 3                23.672212                              NaN
# 4                  4.17497                              NaN
# 5                -2.945959                              NaN
# 6                      NaN                              NaN
#
#   Change % YoYIncome before taxes Change % YoY Diluted Earnings per share  \
# 1                             NaN                                     NaN
# 2                       41.816547                                     NaN
# 3                       29.074192                                     NaN
# 4                        0.417588                                     NaN
# 5                       -5.014677                                     NaN
# 6                             NaN                                     NaN
#
#   Change % YoYDiluted Earnings per share  \
# 1                                    NaN
# 2                              38.877339
# 3                               8.383234
# 4                               40.19337
# 5                             -14.384236
# 6                                    NaN
#
#   Change % YoY Net income available to common shareholders  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#   Change % YoYNet income available to common shareholders
# 1                                                NaN
# 2                                          41.694025
# 3                                           9.731233
# 4                                          37.373311
# 5                                         -15.431909
# 6                                                NaN
#
# [6 rows x 36 columns]

# %% [markdown]
# ### Main loop
#
# Putting together IncomeStatement of all tickers

# %%
files = os.listdir('data/IncomeStatement/')

tickers_downloaded = set()

for f in files:
    tickers_downloaded.add(f.split(' ')[0].split('-')[0])
    
tickers_downloaded = sorted(list(tickers_downloaded))

# %%
# Descarga la información...
# ... PENDING ...

# Procesa la información
Statement_type = 'IncomeStatement'
period = 'annual' # 'quarterly' # 'annual'

# Listing all files
files = os.listdir('data/' + Statement_type + '/')

Fundamentals = pd.DataFrame()

for t in tickers_downloaded:    # tickers
    # Look for file
    for f in files:  
        if t in f and period in f:  
            filename = f
    
#    print(filename)
    df_ticker = create_df_ticker(t, Statement_type, filename)
    
    if Fundamentals.shape == (0,0):
        Fundamentals = df_ticker
    else:
        Fundamentals = pd.concat([Fundamentals, df_ticker])

Fundamentals.head(50)
# Out:
# <ipython-input-11-91193cecf54b>:36: RuntimeWarning: invalid value encountered in double_scalars
#   income_ticker.loc['Change % YoY' + x, y] = (income_ticker.loc[x, y] / income_ticker.loc[x, str(int(y)-1)] - 1) * 100
# <ipython-input-11-91193cecf54b>:36: RuntimeWarning: divide by zero encountered in double_scalars
#   income_ticker.loc['Change % YoY' + x, y] = (income_ticker.loc[x, y] / income_ticker.loc[x, str(int(y)-1)] - 1) * 100
#   Ticker  Year   Revenue Cost of revenue Gross profit  \
# 1      A  2016    3574.0          1932.0       1642.0
# 2      A  2017    3722.0          2012.0       1710.0
# 3      A  2018    4218.0          2237.0       1981.0
# 4      A  2019    4485.0          2385.0       2100.0
# 5      A  2020    4448.0          2445.0       2003.0
# 6      A   TTM    4448.0          2445.0       2003.0
# 1    AAL  2016   40180.0         28339.0      11841.0
# 2    AAL  2017   42207.0         31154.0      11053.0
# 3    AAL  2018   44541.0         34490.0      10051.0
# 4    AAL  2019   45768.0         35379.0      10389.0
# 5    AAL  2020   17337.0         24933.0      -7596.0
# 6    AAL   TTM   17337.0         24933.0      -7596.0
# 1    AAP  2016  215639.0        131376.0      84263.0
# 2    AAP  2017  229234.0        141048.0      88186.0
# 3    AAP  2018  265595.0        163756.0     101839.0
# 4    AAP  2019  260174.0        161782.0      98392.0
# 5    AAP  2020  274515.0        169559.0     104956.0
# 6    AAP   TTM  294135.0        180068.0     114067.0
# 1   AAPL  2016  215639.0        131376.0      84263.0
# 2   AAPL  2017  229234.0        141048.0      88186.0
# 3   AAPL  2018  265595.0        163756.0     101839.0
# 4   AAPL  2019  260174.0        161782.0      98392.0
# 5   AAPL  2020  274515.0        169559.0     104956.0
# 6   AAPL   TTM  294135.0        180068.0     114067.0
# 1   ABBV  2016   25638.0          5833.0      19805.0
# 2   ABBV  2017   28216.0          7040.0      21176.0
# 3   ABBV  2018   32753.0          7718.0      25035.0
# 4   ABBV  2019   33266.0          7439.0      25827.0
# 5   ABBV  2020   45804.0         15387.0      30417.0
# 6   ABBV   TTM   45804.0         15387.0      30417.0
# 1    ABC  2016  146850.0        142577.0       4273.0
# 2    ABC  2017  153144.0        148598.0       4546.0
# 3    ABC  2018  167940.0        163327.0       4612.0
# 4    ABC  2019  179589.0        174451.0       5138.0
# 5    ABC  2020  189894.0        184702.0       5192.0
# 6    ABC   TTM  194546.0        189133.0       5413.0
# 1   ABMD  2016     330.0            50.0        279.0
# 2   ABMD  2017     445.0            71.0        375.0
# 3   ABMD  2018     594.0            99.0        495.0
# 4   ABMD  2019     769.0           130.0        640.0
# 5   ABMD  2020     841.0           151.0        690.0
# 6   ABMD   TTM     813.0           155.0        658.0
# 1    ABT  2016   20853.0          9024.0      11829.0
# 2    ABT  2017   27390.0         12337.0      15053.0
# 3    ABT  2018   30578.0         12706.0      17872.0
# 4    ABT  2019   31904.0         13231.0      18673.0
# 5    ABT  2020   34608.0         15003.0      19605.0
# 6    ABT   TTM   34608.0         15003.0      19605.0
# 1    ACN  2016   34798.0         24520.0      10277.0
# 2    ACN  2017   36765.0         25735.0      11030.0
#
#   Research and development Sales, General and administrative  \
# 1                    376.0                             751.0
# 2                    389.0                             749.0
# 3                    444.0                             811.0
# 4                    447.0                             826.0
# 5                    453.0                             787.0
# 6                    453.0                             787.0
# 1                      NaN                            1323.0
# 2                      NaN                            1477.0
# 3                      NaN                            1520.0
# 4                      NaN                            1602.0
# 5                      NaN                             513.0
# 6                      NaN                             513.0
# 1                  10045.0                           14194.0
# 2                  11581.0                           15261.0
# 3                  14236.0                           16705.0
# 4                  16217.0                           18245.0
# 5                  18752.0                           19916.0
# 6                  19464.0                           20350.0
# 1                  10045.0                           14194.0
# 2                  11581.0                           15261.0
# 3                  14236.0                           16705.0
# 4                  16217.0                           18245.0
# 5                  18752.0                           19916.0
# 6                  19464.0                           20350.0
# 1                   4366.0                            5855.0
# 2                   4982.0                            6275.0
# 3                  10329.0                            7399.0
# 4                   6407.0                            6942.0
# 5                   6557.0                           11299.0
# 6                   6557.0                           11299.0
# 1                      NaN                            2091.0
# 2                      NaN                            2129.0
# 3                      NaN                            2460.0
# 4                      NaN                            2664.0
# 5                      NaN                            2767.0
# 6                      NaN                            2816.0
# 1                     50.0                             164.0
# 2                     66.0                             218.0
# 3                     75.0                             263.0
# 4                     94.0                             322.0
# 5                     99.0                             342.0
# 6                    115.0                             318.0
# 1                   1422.0                            6672.0
# 2                   2235.0                            9117.0
# 3                   2300.0                            9744.0
# 4                   2440.0                            9765.0
# 5                   2420.0                            9696.0
# 6                   2420.0                            9696.0
# 1                      NaN                            5467.0
# 2                      NaN                            6398.0
#
#   Restructuring, merger and acquisition Other operating expenses  \
# 1                                 144.0                     85.0
# 2                                  66.0                    118.0
# 3                                  19.0                     78.0
# 4                                  32.0                     71.0
# 5                                  34.0                     44.0
# 6                                  34.0                     44.0
# 1                                   NaN                   4525.0
# 2                                 505.0                   4481.0
# 3                                 748.0                   4384.0
# 4                                 473.0                   4627.0
# 5                                1408.0                   1789.0
# 6                                1408.0                   1789.0
# 1                                   NaN                      NaN
# 2                                   NaN                      NaN
# 3                                   NaN                      NaN
# 4                                   NaN                      NaN
# 5                                   NaN                      NaN
# 6                                   NaN                      NaN
# 1                                   NaN                      NaN
# 2                                   NaN                      NaN
# 3                                   NaN                      NaN
# 4                                   NaN                      NaN
# 5                                   NaN                      NaN
# 6                                   NaN                      NaN
# 1                                   NaN                      NaN
# 2                                   NaN                      NaN
# 3                                   NaN                    500.0
# 4                                   NaN                   -890.0
# 5                                   NaN                      NaN
# 6                                   NaN                      NaN
# 1                                  73.0                    292.0
# 2                                  45.0                    353.0
# 3                                 122.0                    343.0
# 4                                 145.0                    317.0
# 5                                  85.0                    306.0
# 6                                 109.0                    277.0
# 1                                   NaN                      NaN
# 2                                   NaN                      NaN
# 3                                   NaN                      NaN
# 4                                   NaN                      NaN
# 5                                   NaN                      NaN
# 6                                   NaN                      NaN
# 1                                   NaN                    550.0
# 2                                   NaN                   1975.0
# 3                                   NaN                   2178.0
# 4                                   NaN                   1936.0
# 5                                   NaN                   2132.0
# 6                                   NaN                   2132.0
# 1                                   NaN                      NaN
# 2                                   NaN                      NaN
#
#   Total operating expenses  ... Change % YoYIncome before taxes  \
# 1                   1356.0  ...                             NaN
# 2                   1322.0  ...                     -168.217054
# 3                   1352.0  ...                      495.454545
# 4                   1376.0  ...                       14.122137
# 5                   1318.0  ...                       -6.354515
# 6                   1318.0  ...                             NaN
# 1                   5848.0  ...                             NaN
# 2                   6463.0  ...                      -28.262387
# 3                   6652.0  ...                      -38.910506
# 4                   6702.0  ...                       19.745223
# 5                   3710.0  ...                      -607.66844
# 6                   3710.0  ...                             NaN
# 1                  24239.0  ...                             NaN
# 2                  26842.0  ...                          4.4271
# 3                  30941.0  ...                        13.75275
# 4                  34462.0  ...                       -9.829499
# 5                  38668.0  ...                        2.059723
# 6                  39814.0  ...                             NaN
# 1                  24239.0  ...                             NaN
# 2                  26842.0  ...                          4.4271
# 3                  30941.0  ...                        13.75275
# 4                  34462.0  ...                       -9.829499
# 5                  38668.0  ...                        2.059723
# 6                  39814.0  ...                             NaN
# 1                  10221.0  ...                             NaN
# 2                  11257.0  ...                       -1.991375
# 3                  18228.0  ...                      -32.742332
# 4                  12459.0  ...                       62.131999
# 5                  17856.0  ...                      -59.672442
# 6                  17856.0  ...                             NaN
# 1                   2456.0  ...                             NaN
# 2                   2526.0  ...                      -34.004313
# 3                   2925.0  ...                       28.213508
# 4                   3126.0  ...                      -17.841971
# 5                   3158.0  ...                     -647.466391
# 6                   3202.0  ...                             NaN
# 1                    214.0  ...                             NaN
# 2                    285.0  ...                       37.878788
# 3                    338.0  ...                       75.824176
# 4                    415.0  ...                          64.375
# 5                    440.0  ...                       -2.281369
# 6                    433.0  ...                             NaN
# 1                   8644.0  ...                             NaN
# 2                  13327.0  ...                       57.891012
# 3                  14222.0  ...                       28.776333
# 4                  14141.0  ...                       41.907414
# 5                  14248.0  ...                       21.854305
# 6                  14248.0  ...                             NaN
# 1                   5467.0  ...                             NaN
# 2                   6398.0  ...                      -17.630264
#
#   Change % YoY Diluted Earnings per share  \
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 1                                     NaN
# 2                                     NaN
#
#   Change % YoYDiluted Earnings per share  \
# 1                                    NaN
# 2                            -112.075472
# 3                                 2325.0
# 4                              28.479381
# 5                              -6.218656
# 6                                    NaN
# 1                                    NaN
# 2                             -18.918919
# 3                             -22.307692
# 4                              25.082508
# 5                            -584.432718
# 6                                    NaN
# 1                                    NaN
# 2                              10.576923
# 3                              29.565217
# 4                               -0.33557
# 5                               10.43771
# 6                                    NaN
# 1                                    NaN
# 2                              10.576923
# 3                              29.565217
# 4                               -0.33557
# 5                               10.43771
# 6                                    NaN
# 1                                    NaN
# 2                              -9.090909
# 3                              10.909091
# 4                              44.262295
# 5                             -48.484848
# 6                                    NaN
# 1                                    NaN
# 2                             -74.050633
# 3                             359.146341
# 4                             -46.347942
# 5                            -512.128713
# 6                                    NaN
# 1                                    NaN
# 2                              37.647059
# 3                             109.401709
# 4                             128.979592
# 5                             -21.033868
# 6                                    NaN
# 1                                    NaN
# 2                             -71.276596
# 3                             392.592593
# 4                              54.887218
# 5                              21.359223
# 6                                    NaN
# 1                                    NaN
# 2                             -15.658915
#
#   Change % YoY Net income available to common shareholders  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   Change % YoYNet income available to common shareholders  Other  \
# 1                                                NaN         NaN
# 2                                        -112.408759         NaN
# 3                                        2376.470588         NaN
# 4                                          29.216152         NaN
# 5                                          -7.352941         NaN
# 6                                                NaN         NaN
# 1                                                NaN         NaN
# 2                                          -28.28849         NaN
# 3                                          -26.42001         NaN
# 4                                          19.405099         NaN
# 5                                        -626.986951         NaN
# 6                                                NaN         NaN
# 1                                                NaN         NaN
# 2                                            5.83098         NaN
# 3                                          23.122583         NaN
# 4                                          -7.181133         NaN
# 5                                           3.900029         NaN
# 6                                                NaN         NaN
# 1                                                NaN         NaN
# 2                                            5.83098         NaN
# 3                                          23.122583         NaN
# 4                                          -7.181133         NaN
# 5                                           3.900029         NaN
# 6                                                NaN         NaN
# 1                                                NaN         NaN
# 2                                         -10.805335         NaN
# 3                                           7.079311         NaN
# 4                                          38.624713         NaN
# 5                                         -41.902576        -6.0
# 6                                                NaN        -6.0
# 1                                                NaN         NaN
# 2                                         -74.509804         NaN
# 3                                         355.494505        43.0
# 4                                         -48.431846         1.0
# 5                                         -498.71345        -9.0
# 6                                                NaN       -14.0
# 1                                                NaN         NaN
# 2                                          36.842105         NaN
# 3                                         115.384615         NaN
# 4                                             131.25         NaN
# 5                                         -21.621622         NaN
# 6                                                NaN         NaN
# 1                                                NaN         NaN
# 2                                         -65.928571         NaN
# 3                                         396.436059         NaN
# 4                                          55.701014         NaN
# 5                                          21.914836         NaN
# 6                                                NaN         NaN
# 1                                                NaN      -238.0
# 2                                         -16.220817      -190.0
#
#   Preferred dividend Net income from discontinuing ops Other income  \
# 1                NaN                               NaN          NaN
# 2                NaN                               NaN          NaN
# 3                NaN                               NaN          NaN
# 4                NaN                               NaN          NaN
# 5                NaN                               NaN          NaN
# 6                NaN                               NaN          NaN
# 1                NaN                               NaN          NaN
# 2                NaN                               NaN          NaN
# 3                NaN                               NaN          NaN
# 4                NaN                               NaN          NaN
# 5                NaN                               NaN          NaN
# 6                NaN                               NaN          NaN
# 1                NaN                               NaN          NaN
# 2                NaN                               NaN          NaN
# 3                NaN                               NaN          NaN
# 4                NaN                               NaN          NaN
# 5                NaN                               NaN          NaN
# 6                NaN                               NaN          NaN
# 1                NaN                               NaN          NaN
# 2                NaN                               NaN          NaN
# 3                NaN                               NaN          NaN
# 4                NaN                               NaN          NaN
# 5                NaN                               NaN          NaN
# 6                NaN                               NaN          NaN
# 1               30.0                               NaN          NaN
# 2               26.0                               NaN          NaN
# 3               30.0                               NaN          NaN
# 4               40.0                               NaN          NaN
# 5               60.0                               NaN          NaN
# 6               60.0                               NaN          NaN
# 1                NaN                               NaN          NaN
# 2                NaN                               NaN          NaN
# 3                NaN                               NaN          NaN
# 4                NaN                               NaN          NaN
# 5                NaN                               NaN          NaN
# 6                NaN                               NaN          NaN
# 1                NaN                               NaN          NaN
# 2                NaN                               NaN          NaN
# 3                NaN                               NaN          NaN
# 4                NaN                               NaN          NaN
# 5                NaN                               NaN          NaN
# 6                NaN                               NaN          NaN
# 1                NaN                             337.0          NaN
# 2                NaN                             124.0          NaN
# 3                NaN                              34.0          NaN
# 4                NaN                               NaN          NaN
# 5                NaN                              24.0          NaN
# 6                NaN                              24.0          NaN
# 1                NaN                               NaN          NaN
# 2                NaN                               NaN          NaN
#
#   Extraordinary items
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 1                 NaN
# 2                 NaN
#
# [50 rows x 40 columns]

# %%
sorted(Fundamentals.columns)
# Out:
# ['Basic Earnings per share',
#  'Basic Weighted average shares outstanding',
#  'Change % YoY Cost of revenue',
#  'Change % YoY Diluted Earnings per share',
#  'Change % YoY Gross profit',
#  'Change % YoY Income before taxes',
#  'Change % YoY Net income available to common shareholders',
#  'Change % YoY Revenue',
#  'Change % YoYCost of revenue',
#  'Change % YoYDiluted Earnings per share',
#  'Change % YoYGross profit',
#  'Change % YoYIncome before taxes',
#  'Change % YoYNet income available to common shareholders',
#  'Change % YoYRevenue',
#  'Cost of revenue',
#  'Diluted Earnings per share',
#  'Diluted Weighted average shares outstanding',
#  'EBITDA',
#  'Extraordinary items',
#  'Gross profit',
#  'Income before taxes',
#  'Interest Expense',
#  'Net income',
#  'Net income available to common shareholders',
#  'Net income from continuing operations',
#  'Net income from discontinuing ops',
#  'Operating income',
#  'Other',
#  'Other income',
#  'Other income (expense)',
#  'Other operating expenses',
#  'Preferred dividend',
#  'Provision for income taxes',
#  'Research and development',
#  'Restructuring, merger and acquisition',
#  'Revenue',
#  'Sales, General and administrative',
#  'Ticker',
#  'Total operating expenses',
#  'Year']
